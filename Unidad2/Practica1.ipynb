# %% [markdown]
# <a href="https://colab.research.google.com/github/luizhernandez129/Simulacion/blob/main/Unidad2/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simulacion
# Unidad 2
# Practica 1
# Luis Martin Pereyra Hernandez

# %%
# Semilla inicial
semilla=2005
n=4
iteraciones=100
resultados=[]

for _ in range(iteraciones):
  # Elevar la semilla al cuadrado
  cuadrado = str(semilla**2).zfill(2*n) #Agragar los espacios necesarios
  # Extraer los digitos centrales
  inicio = (len(cuadrado) - n ) // 2
  semilla = int(cuadrado[inicio:inicio + n])
  resultados.append(semilla)

  # Imprimir los resultados
  for i, numero in enumerate(resultados, 1):
    print (f"Numero Aleatorio {i}: {numero}")
# Out:
# Numero Aleatorio 1: 200
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 3: 1600
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 3: 1600
# Numero Aleatorio 4: 5600
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 3: 1600
# Numero Aleatorio 4: 5600
# Numero Aleatorio 5: 3600
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 3: 1600
# Numero Aleatorio 4: 5600
# Numero Aleatorio 5: 3600
# Numero Aleatorio 6: 9600
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 3: 1600
# Numero Aleatorio 4: 5600
# Numero Aleatorio 5: 3600
# Numero Aleatorio 6: 9600
# Numero Aleatorio 7: 1600
# Numero Aleatorio 1: 200
# Numero Aleatorio 2: 400
# Numero Aleatorio 3: 1600
# Numero Aleatorio 4: 5600
# Numero Aleatorio 5: 3600
# Numero Aleatorio 6: 9600
# Numero Aleatorio 7: 1600
# Numero Aleatorio 8: 5600
# Numero Aleatorio 1: 200
# ...
